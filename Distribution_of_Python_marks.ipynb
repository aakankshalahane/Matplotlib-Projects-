# %% [markdown]
# <a href="https://colab.research.google.com/github/aakankshalahane/Matplotlib-Projects-/blob/main/Distribution_of_Python_marks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample DataFrame creation to resolve 'df is not defined'
data = {'Python': [70, 85, 60, 90, 75, 80, 65, 95, 70, 85, 55, 100]}
df = pd.DataFrame(data)

plt.figure(figsize=(8, 5))

plt.hist(df["Python"], bins=5, edgecolor="black")

plt.title("Distribution of Python Marks")
plt.xlabel("Marks")
plt.ylabel("Number of Students")

plt.show()
