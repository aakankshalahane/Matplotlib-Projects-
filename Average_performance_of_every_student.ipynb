# %% [markdown]
# <a href="https://colab.research.google.com/github/aakankshalahane/Matplotlib-Projects-/blob/main/Average_performance_of_every_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create a sample DataFrame 'df'
data = {
    "Student": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "Average": [85, 90, 78, 92, 88]
}
df = pd.DataFrame(data)

plt.figure(figsize=(10, 5))

plt.barh(df["Student"], df["Average"])

plt.title("Average Performance of Students")
plt.xlabel("Average Marks")
plt.ylabel("Student")

plt.show()
