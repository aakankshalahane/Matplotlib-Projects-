# %% [markdown]
# <a href="https://colab.research.google.com/github/aakankshalahane/Matplotlib-Projects-/blob/main/Best_performing_students.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

df["Average"] = df[subjects].mean(axis=1)

top_students = df.sort_values("Average", ascending=False).head(5)

plt.figure(figsize=(8, 5))

plt.bar(top_students["Student"], top_students["Average"])

plt.title("Top 5 Students by Average Marks")
plt.xlabel("Student")
plt.ylabel("Average Marks")

plt.show()

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    'Student': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Heidi', 'Ivan', 'Judy'],
    'Math': [85, 90, 78, 92, 88, 75, 95, 80, 83, 89],
    'Science': [90, 85, 88, 70, 91, 82, 79, 93, 87, 77],
    'English': [78, 92, 85, 88, 90, 80, 84, 76, 91, 86]
}
df = pd.DataFrame(data)

# Define the subjects for calculating average
subjects = ['Math', 'Science', 'English']

display(df.head())
# Out:
#    Student  Math  Science  English
# 0    Alice    85       90       78
# 1      Bob    90       85       92
# 2  Charlie    78       88       85
# 3    David    92       70       88
# 4      Eve    88       91       90
