# %% [markdown]
# <a href="https://colab.research.google.com/github/aakankshalahane/Matplotlib-Projects-/blob/main/Student_Performance_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


# 1. Create a small dataset

data = {
    "Student": ["Aarav", "Riya", "Karan", "Sneha", "Rahul",
                "Priya", "Aditya", "Neha", "Vikram", "Ananya"],

    "Maths": [78, 92, 65, 88, 72, 95, 81, 69, 84, 90],

    "Python": [85, 89, 70, 91, 76, 94, 88, 73, 82, 96],

    "Database": [74, 87, 68, 85, 79, 91, 83, 71, 80, 89],

    "Study_Hours": [5, 8, 3, 7, 4, 9, 6, 3, 5, 8]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Student  Maths  Python  Database  Study_Hours
# 0   Aarav     78      85        74            5
# 1    Riya     92      89        87            8
# 2   Karan     65      70        68            3
# 3   Sneha     88      91        85            7
# 4   Rahul     72      76        79            4
# 5   Priya     95      94        91            9
# 6  Aditya     81      88        83            6
# 7    Neha     69      73        71            3
# 8  Vikram     84      82        80            5
# 9  Ananya     90      96        89            8
